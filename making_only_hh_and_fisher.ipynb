# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
# Out:
# Mounted at /content/drive

# %%
years_2011_13_only_hhfisher = pd.read_csv('/content/drive/MyDrive/12_12_24_datarevisiting/new_patients_2011_2013_hh_fisher.csv')
years_2014_16_only_hhfisher = pd.read_csv('/content/drive/MyDrive/12_12_24_datarevisiting/new_patients_2014_2016_hh_fisher.csv')

# %%
years_2011_13_only_hhfisher.head()
# Out:
#     hadm_id                                           ASM_Drug  \
# 0  20059464  Phenytoin Sodium, Phenytoin (Suspension), Phen...
# 1  20089438  Phenytoin Sodium, Phenytoin Sodium, LeVETirace...
# 2  20179837                                                NaN
# 3  20196181  LeVETiracetam, LeVETiracetam Oral Solution, Le...
# 4  20259763                                                NaN
#
#          ASM_Starttime         ASM_Stoptime  icd_code  subject_id  \
# 0   2176-12-08 8:00:00  2176-12-12 21:00:00       430    17752593
# 1  2179-12-23 18:00:00  2180-01-17 19:00:00       430    16691089
# 2                  NaN                  NaN       430    12528320
# 3  2159-09-01 14:00:00  2159-09-14 19:00:00       430    17003151
# 4                  NaN                  NaN       430    10795512
#
#   anchor_year_group  dod   race            admittime  ... los_hospital  \
# 0       2011 - 2013  NaN  WHITE  2176-12-07 18:35:00  ...          5.0
# ...

# %%
years_2011_13_only_hhfisher = years_2011_13_only_hhfisher[~years_2011_13_only_hhfisher['Fisher'].isna()]

# %%
years_2011_13_only_hhfisher.head()
# Out:
#      hadm_id                                           ASM_Drug  \
# 5   20308330  Phenytoin Sodium, Phenytoin Sodium, Phenytoin ...
# 7   20393299  LeVETiracetam, LeVETiracetam, LeVETiracetam, L...
# 8   20408101  LeVETiracetam, LeVETiracetam, LeVETiracetam, L...
# 9   20454348  Phenytoin Infatab, Phenytoin Sodium, Phenytoin...
# 11  20495450  LeVETiracetam, LeVETiracetam Oral Solution, Le...
#
#           ASM_Starttime         ASM_Stoptime  icd_code  subject_id  \
# 5    2114-11-03 5:00:00  2114-11-07 13:00:00       430    16578570
# 7   2178-01-27 12:00:00  2178-02-19 19:00:00       430    15057621
# 8    2171-10-22 8:00:00   2171-11-06 1:00:00       430    10261808
# 9   2135-09-18 23:00:00  2135-09-26 18:00:00       430    15981763
# 11  2118-06-29 20:00:00  2118-08-03 19:00:00       430    18730144
#
#    anchor_year_group         dod     race            admittime  ...  \
# 5        2011 - 2013  2124-08-25    WHITE   2114-11-03 3:00:00  ...
# ...

# %%
years_2011_13_only_hhfisher.to_csv('/content/drive/MyDrive/12_12_24_datarevisiting/only_fishers_2011_2013.csv')

# %%
years_2014_16_only_hhfisher = years_2014_16_only_hhfisher[~years_2014_16_only_hhfisher['Fisher'].isna()]

# %%
years_2014_16_only_hhfisher.to_csv('/content/drive/MyDrive/12_12_24_datarevisiting/only_fishers_2014_2016.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/12_12_24_datarevisiting/III_discerned_only_fishers_2011_2013.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   hadm_id                                           ASM_Drug  \
# 0           5  20308330  Phenytoin Sodium, Phenytoin Sodium, Phenytoin ...
# 1           7  20393299  LeVETiracetam, LeVETiracetam, LeVETiracetam, L...
# 2           8  20408101  LeVETiracetam, LeVETiracetam, LeVETiracetam, L...
# 3           9  20454348  Phenytoin Infatab, Phenytoin Sodium, Phenytoin...
# 4          11  20495450  LeVETiracetam, LeVETiracetam Oral Solution, Le...
#
#          ASM_Starttime         ASM_Stoptime  icd_code  subject_id  \
# 0   2114-11-03 5:00:00  2114-11-07 13:00:00       430    16578570
# 1  2178-01-27 12:00:00  2178-02-19 19:00:00       430    15057621
# 2   2171-10-22 8:00:00   2171-11-06 1:00:00       430    10261808
# 3  2135-09-18 23:00:00  2135-09-26 18:00:00       430    15981763
# 4  2118-06-29 20:00:00  2118-08-03 19:00:00       430    18730144
#
#   anchor_year_group         dod     race  ... Minimum_Creatinine  \
# ...

# %%
filtered_df = df[df['in_III'].isna()]

# %%
filtered_df.head()
# Out:
#    Unnamed: 0   hadm_id                                           ASM_Drug  \
# 0           5  20308330  Phenytoin Sodium, Phenytoin Sodium, Phenytoin ...
# 1           7  20393299  LeVETiracetam, LeVETiracetam, LeVETiracetam, L...
# 2           8  20408101  LeVETiracetam, LeVETiracetam, LeVETiracetam, L...
# 3           9  20454348  Phenytoin Infatab, Phenytoin Sodium, Phenytoin...
# 4          11  20495450  LeVETiracetam, LeVETiracetam Oral Solution, Le...
#
#          ASM_Starttime         ASM_Stoptime  icd_code  subject_id  \
# 0   2114-11-03 5:00:00  2114-11-07 13:00:00       430    16578570
# 1  2178-01-27 12:00:00  2178-02-19 19:00:00       430    15057621
# 2   2171-10-22 8:00:00   2171-11-06 1:00:00       430    10261808
# 3  2135-09-18 23:00:00  2135-09-26 18:00:00       430    15981763
# 4  2118-06-29 20:00:00  2118-08-03 19:00:00       430    18730144
#
#   anchor_year_group         dod     race  ... Minimum_Creatinine  \
# ...

# %%
filtered_df.to_csv('/content/drive/MyDrive/12_12_24_datarevisiting/1113_toread.csv')
